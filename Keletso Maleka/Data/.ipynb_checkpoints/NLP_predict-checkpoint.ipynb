# %%
import pandas as pd
import matplotlib.pyplot as plt
import spacy
nlp = spacy.load('en_core_web_lg')

# %%
train = pd.read_csv('train.csv')

# %%
v = list(train['sentiment'].value_counts())

# %%
counts = train.groupby('sentiment').agg(len)

# %%
train['sentiment'].value_counts()
# Out:
#  1    8530
#  2    3640
#  0    2353
# -1    1296
# Name: sentiment, dtype: int64

# %%
counts.reset_index(inplace=True)

# %%
counts.plot(x = 'sentiment', y= 'message',kind= 'bar')

# %%
v
# Out:
# [8530, 3640, 2353, 1296]

# %%
percentages = [(i/sum(v))*100 for i in v]

# %%
percentages
# Out:
# [53.922498261584174, 23.010304064732285, 14.87451798470194, 8.192679688981604]

# %%
News = train[train['sentiment'] == 2]
Pro = train[train['sentiment'] == 1]
Neutral = train[train['sentiment'] == 0]
Anti = train[train['sentiment'] == -1]

# %%
train['doc'] = [nlp(text) for text in train.message]

# %%
train.head()
# Out:
#    sentiment                                            message  tweetid  \
# 0          1  PolySciMajor EPA chief doesn't think carbon di...   625221
# 1          1  It's not like we lack evidence of anthropogeni...   126103
# 2          2  RT @RawStory: Researchers say we have three ye...   698562
# 3          1  #TodayinMaker# WIRED : 2016 was a pivotal year...   573736
# 4          1  RT @SoyNovioDeTodas: It's 2016, and a racist, ...   466954
#
#                                                  doc
# 0  (PolySciMajor, EPA, chief, does, n't, think, c...
# 1  (It, 's, not, like, we, lack, evidence, of, an...
# 2  (RT, @RawStory, :, Researchers, say, we, have,...
# 3  (#, TodayinMaker, #, WIRED, :, 2016, was, a, p...
# 4  (RT, @SoyNovioDeTodas, :, It, 's, 2016, ,, and...

# %%
train['num_tokens'] = [len(token) for token in train['doc']]

# %%
train.head()
# Out:
#    sentiment                                            message  tweetid  \
# 0          1  PolySciMajor EPA chief doesn't think carbon di...   625221
# 1          1  It's not like we lack evidence of anthropogeni...   126103
# 2          2  RT @RawStory: Researchers say we have three ye...   698562
# 3          1  #TodayinMaker# WIRED : 2016 was a pivotal year...   573736
# 4          1  RT @SoyNovioDeTodas: It's 2016, and a racist, ...   466954
#
#                                                  doc  num_tokens
# 0  (PolySciMajor, EPA, chief, does, n't, think, c...          24
# 1  (It, 's, not, like, we, lack, evidence, of, an...          11
# 2  (RT, @RawStory, :, Researchers, say, we, have,...          22
# 3  (#, TodayinMaker, #, WIRED, :, 2016, was, a, p...          17
# 4  (RT, @SoyNovioDeTodas, :, It, 's, 2016, ,, and...          25

# %%
train['countDict'] = train['doc'].apply(lambda x: [token.pos_ for token in x])

# %%
train
# Out:
#        sentiment                                            message  tweetid  \
# 0              1  PolySciMajor EPA chief doesn't think carbon di...   625221
# 1              1  It's not like we lack evidence of anthropogeni...   126103
# 2              2  RT @RawStory: Researchers say we have three ye...   698562
# 3              1  #TodayinMaker# WIRED : 2016 was a pivotal year...   573736
# 4              1  RT @SoyNovioDeTodas: It's 2016, and a racist, ...   466954
# 5              1  Worth a read whether you do or don't believe i...   425577
# 6              1  RT @thenation: Mike Pence doesn’t believe in g...   294933
# 7              1  RT @makeandmendlife: Six big things we can ALL...   992717
# 8              1  @AceofSpadesHQ My 8yo nephew is inconsolable. ...   664510
#                                                      doc  num_tokens  \
# 0      (PolySciMajor, EPA, chief, does, n't, think, c...          24
# 1      (It, 's, not, like, we, lack, evidence, of, an...          11
# 2      (RT, @RawStory, :, Researchers, say, we, have,...          22
# 3      (#, TodayinMaker, #, WIRED, :, 2016, was, a, p...          17
# 4      (RT, @SoyNovioDeTodas, :, It, 's, 2016, ,, and...          25
# 5      (Worth, a, read, whether, you, do, or, do, n't...          15
# 6      (RT, @thenation, :, Mike, Pence, does, n’t, be...          19
# 7      (RT, @makeandmendlife, :, Six, big, things, we...          27
# 8      (@AceofSpadesHQ, My, 8yo, nephew, is, inconsol...          28
# 9      (RT, @paigetweedy, :, no, offense, …, but, lik...          21
# 10     (RT, @StephenSchlegel, :, she, 's, thinking, a...          24
# 11     (I, do, hope, people, who, are, vocal, about, ...          20
# 12     (RT, @tveitdal, :, We, only, have, a, 5, perce...          23
# 13     (RT, @Alifaith55, :, Oh, ., My, ., God, ., \n\...          28
# 14     (Fossil, fuel, giant, ExxonMobil, ‘, misled’, ...          16
# 15     (RT, @GlblCtzn, :, ', I, do, n't, wanna, live,...          28
# 16     (RT, @jackholmes0, :, Issues, scrubbed, from, ...          19
# 17     (RT, @patagonia, :, If, our, elected, leaders,...          31
# 18     (RT, @SenSanders, :, We, have, a, president, -...          30
# 19     (Calum, :, *, tweets, abt, reunitingish, w, th...          31
# 20     (RT, @c40cities, :, 46, C40, Mayors, ,, repres...          26
# 21     (RT, @World_Wildlife, :, How, climate, change,...          15
# 22     (we, also, met, this, guy, ,, he, let, us, in,...          22
# 23     (https://t.co/KyNIBjmDk5, \n, Scientists, say,...          20
# 24     (RT, @TammyGrubb, :, Obama, raises, climate, c...          20
# 25     (I, hate, to, say, this, ,, but, *, mental, *,...          28
# 26     (Bangladesh, confronting, climate, change, hea...           8
# 27     (Hey, There, !, Michael, 's, vetted, and, appr...          26
# 28     (Sally, Kohn, ’s, latest, evidence, of, climat...          23
# 29     (RT, @StarTalkRadio, :, First, :, The, public,...          24
# ...                                                  ...         ...
# 15789  (Denying, evidence, of, climate, change, is, l...          24
# 15790  (RT, @CleanAirMoms_FL, :, .@DCCC, fighting, cl...          26
# 15791  (He, is, Instagramming, about, the, dangers, o...          12
# 15792  (Trumps, actions, on, climate, change, are, an...          11
# 15793  (Suicides, of, nearly, 60000, Indian, farmers,...          17
# 15794  (Denying, climate, change, is, real, ,, but, s...          15
# 15795  (China, ’s, coal, use, drops, ,, showing, comm...          14
# 15796  (RT, @BreBarra, :, It, 's, time, to, give, up,...          26
# 15797  (@realDonaldTrump, Damn, China, &, amp, ;, the...          20
# 15798  (Dams, raise, global, warming, gas, :, SciDev,...          15
# 15799  (RT, @SethMacFarlane, :, HRC, proposes, instal...          27
# 15800  (RT, @sapinker, :, The, only, practical, way, ...          19
# 15801  (RT, @SenSanders, :, On, virtually, every, maj...          26
# 15802  (Michael, Bloomberg, to, world, leaders, :, ig...          12
# 15803  (Suicides, of, nearly, 60,000, Indian, farmers...          15
# 15804  (RT, @cathdweeb, :, me, with, full, knowledge,...          11
# 15805  (RT, @GrindTV, :, New, head, of, EPA, says, cl...          17
# 15806  (RT, @HerberMp, :, @sness5561_ness, Al, Gore, ...          28
# 15807  (#, scottpruit, climate, change, comments, wou...          29
# 15808  (RT, @ThePowersThatBe, :, Now, if, she, could,...          20
# 15809  (The, quest, to, capture, and, store, carbon, ...          20
# 15810  (This, global, warming, so, late, in, the, sea...          13
# 15811  (RT, @StephenSchlegel, :, she, 's, thinking, a...          24
# 15812  (RT, @SierraClub, :, 2016, :, hottest, year, i...          26
# 15813  (RT, @thinkprogress, :, EPA, head, falsely, cl...          20
# 15814  (RT, @ezlusztig, :, They, took, down, the, mat...          30
# 15815  (RT, @washingtonpost, :, How, climate, change,...          18
# 15816  (notiven, :, RT, :, nytimesworld, :, What, doe...          23
# 15817  (RT, @sara8smiles, :, Hey, liberals, the, clim...          26
# 15818  (RT, @Chet_Cannon, :, .@kurteichenwald, 's, ',...          14
#
#                                                countDict
# 0      [PROPN, PROPN, NOUN, VERB, ADV, VERB, NOUN, NO...
# 1      [PRON, VERB, ADV, ADP, PRON, VERB, NOUN, ADP, ...
# 2      [PROPN, PROPN, PUNCT, NOUN, VERB, PRON, VERB, ...
# 3      [SYM, PROPN, PROPN, PROPN, PUNCT, NUM, VERB, D...
# 4      [PROPN, VERB, PUNCT, PRON, VERB, NUM, PUNCT, C...
# 5      [PROPN, DET, NOUN, ADP, PRON, VERB, CCONJ, VER...
# 6      [PROPN, VERB, PUNCT, PROPN, PROPN, VERB, ADV, ...
# 7      [PROPN, NOUN, PUNCT, NUM, ADJ, NOUN, PRON, VER...
# 8      [VERB, ADJ, NOUN, NOUN, VERB, ADJ, PUNCT, PRON...
# 9      [PROPN, PROPN, PUNCT, DET, NOUN, PUNCT, CCONJ,...
# 10     [PROPN, NOUN, PUNCT, PRON, VERB, VERB, ADP, AD...
# 11     [PRON, VERB, VERB, NOUN, NOUN, VERB, ADJ, ADP,...
# 12     [PROPN, NOUN, PUNCT, PRON, ADV, VERB, DET, NUM...
# 13     [PROPN, PROPN, PUNCT, INTJ, PUNCT, ADJ, PUNCT,...
# 14     [NOUN, NOUN, NOUN, PROPN, NOUN, VERB, DET, NOU...
# 15     [PROPN, PROPN, PUNCT, PUNCT, PRON, VERB, ADV, ...
# 16     [PROPN, NOUN, PUNCT, NOUN, VERB, ADP, NOUN, NO...
# 17     [PROPN, NOUN, PUNCT, ADP, ADJ, VERB, NOUN, VER...
# 18     [PROPN, PROPN, PUNCT, PRON, VERB, DET, NOUN, P...
# 19     [PROPN, PUNCT, PUNCT, NOUN, VERB, NOUN, ADP, D...
# 20     [PROPN, NOUN, PUNCT, NUM, PROPN, PROPN, PUNCT,...
# 21     [PROPN, NOUN, PUNCT, ADV, NOUN, NOUN, VERB, NO...
# 22     [PRON, ADV, VERB, DET, NOUN, PUNCT, PRON, VERB...
# 23     [PROPN, SPACE, NOUN, VERB, NOUN, NOUN, VERB, P...
# 24     [PROPN, PROPN, PUNCT, PROPN, VERB, NOUN, NOUN,...
# 25     [PRON, VERB, PART, VERB, DET, PUNCT, CCONJ, PU...
# 26            [PROPN, VERB, NOUN, NOUN, NOUN, ADP, X, X]
# 27     [INTJ, ADV, PUNCT, PROPN, PART, VERB, CCONJ, V...
# 28     [PROPN, PROPN, PART, ADJ, NOUN, ADP, NOUN, NOU...
# 29     [PROPN, NOUN, PUNCT, ADV, PUNCT, DET, NOUN, VE...
# ...                                                  ...
# 15789  [VERB, NOUN, ADP, NOUN, NOUN, VERB, ADP, VERB,...
# 15790  [PROPN, NOUN, PUNCT, PUNCT, VERB, NOUN, NOUN, ...
# 15791  [PRON, VERB, VERB, ADP, DET, NOUN, ADP, ADJ, N...
# 15792  [VERB, NOUN, ADP, NOUN, NOUN, VERB, DET, NOUN,...
# 15793  [NOUN, ADP, ADV, NUM, ADJ, NOUN, VERB, ADP, NO...
# 15794  [VERB, NOUN, NOUN, VERB, ADJ, PUNCT, CCONJ, AD...
# 15795  [PROPN, PART, NOUN, NOUN, VERB, PUNCT, VERB, N...
# 15796  [PROPN, PROPN, PUNCT, PRON, VERB, NOUN, PART, ...
# 15797  [VERB, PROPN, PROPN, CCONJ, NOUN, PUNCT, ADJ, ...
# 15798  [NOUN, VERB, ADJ, NOUN, NOUN, PUNCT, PROPN, NO...
# 15799  [PROPN, NOUN, PUNCT, PROPN, VERB, VERB, ADJ, D...
# 15800  [PROPN, X, PUNCT, DET, ADJ, ADJ, NOUN, PART, V...
# 15801  [PROPN, PROPN, PUNCT, ADP, ADV, DET, ADJ, NOUN...
# 15802  [PROPN, PROPN, ADP, NOUN, NOUN, PUNCT, VERB, P...
# 15803  [NOUN, ADP, ADV, NUM, ADJ, NOUN, VERB, ADP, NO...
# 15804  [PROPN, PROPN, PUNCT, PRON, ADP, ADJ, NOUN, AD...
# 15805  [PROPN, PROPN, PUNCT, ADJ, NOUN, ADP, PROPN, V...
# 15806  [PROPN, NOUN, PUNCT, VERB, PROPN, PROPN, VERB,...
# 15807  [NOUN, NOUN, NOUN, NOUN, NOUN, VERB, VERB, ADP...
# 15808  [PROPN, PROPN, PUNCT, ADV, ADP, PRON, VERB, AD...
# 15809  [DET, NOUN, PART, VERB, CCONJ, NOUN, NOUN, PUN...
# 15810  [DET, ADJ, NOUN, ADV, ADV, ADP, DET, NOUN, VER...
# 15811  [PROPN, NOUN, PUNCT, PRON, VERB, VERB, ADP, AD...
# 15812  [PROPN, VERB, PUNCT, NUM, PUNCT, ADJ, NOUN, AD...
# 15813  [PROPN, PROPN, PUNCT, PROPN, NOUN, ADV, VERB, ...
# 15814  [PROPN, PROPN, PUNCT, PRON, VERB, PART, DET, N...
# 15815  [PROPN, ADV, PUNCT, ADV, NOUN, NOUN, VERB, VER...
# 15816  [ADJ, PUNCT, PROPN, PUNCT, NOUN, PUNCT, NOUN, ...
# 15817  [PROPN, NOUN, PUNCT, INTJ, NOUN, DET, NOUN, NO...
# 15818  [PROPN, PROPN, PUNCT, PUNCT, PART, PUNCT, NOUN...
#
# [15819 rows x 6 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-57-b165e3e1ba30> in <module>
# ----> 1 from collections import counter
#
# ImportError: cannot import name 'counter' from 'collections' (C:\Users\Dell\Anaconda3\envs\nlp_course\lib\collections\__init__.py)

# %%
News = train[train['sentiment'] == 2]
Pro = train[train['sentiment'] == 1]
Neutral = train[train['sentiment'] == 0]
Anti = train[train['sentiment'] == -1]
